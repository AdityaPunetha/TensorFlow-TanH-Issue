# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaPunetha/TensorFlow-TanH-Issue/blob/main/TanH_issue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

import numpy as np
import tensorflow as tf

print(sys.version)
print(tf.__version__)
print(np.__version__)
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# 2.8.2
# 1.21.6

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Reshape, Activation
from numpy.random import randn

# %%
latent_size = 100
n_nodes = 8 * 8 * 128

# %%
model = Sequential()

model.add(Dense(n_nodes, input_dim=latent_size))
model.add(Reshape((8, 8, 128)))
model.add(Activation("tanh"))

# %%
i = randn(1, latent_size)

# %%
i
# Out:
# array([[ 1.2635719 ,  1.02857412,  2.25807188, -0.89007078,  1.93991776,
#          1.60967663, -0.31948052, -2.21857543,  0.61748315,  1.54093254,
#         -1.90394532, -1.34739302, -0.39293595,  1.94150344,  1.18590089,
#         -0.43593085,  1.31162508, -1.67498491, -0.15370528, -2.14892353,
#         -1.45486447,  1.3202009 , -1.31180346, -1.14960478,  0.6678974 ,
#         -1.31231552, -2.98765763, -0.268104  ,  0.58356891,  0.74651456,
#         -0.61352503, -1.13707136, -0.04430994,  0.58538506, -0.96570006,
#         -1.09617321, -1.23290703, -2.18877936,  1.64269154,  0.38892266,
#          0.15578244,  0.61967724, -0.70608923,  0.21696776,  0.86306043,
#         -1.13938191,  0.64266615, -1.04248116,  1.21476792, -0.20219829,
#         -1.68216641, -0.8534728 , -0.20586675, -0.84825215, -0.43621911,
#         -0.22845378, -0.1878867 , -0.81488008, -0.15691288,  0.79518182,
#         -0.12846454, -1.02234685, -0.8265473 ,  2.41660934, -0.78745259,
# ...

# %%
o = model(i)
print(o)
# Out:
# tf.Tensor(
# [[[[-1.54229015e-01  1.25226483e-01 -1.09165028e-01 ... -2.03672990e-01
#     -2.07603619e-01  1.03481293e-01]
#    [-3.58494133e-01  1.20092221e-01 -6.67666495e-02 ... -2.85634935e-01
#      2.57372618e-01  7.08528459e-02]
#    [-1.23493597e-01 -9.55593586e-02 -1.65751338e-01 ... -2.93499269e-02
#      9.67467353e-02  8.62120315e-02]
#    ...
#    [-1.56547308e-01  2.74716667e-03  3.98397967e-02 ...  1.15948126e-01
#     -8.71890113e-02  2.58930385e-01]
#    [ 1.39622316e-01  2.89782286e-01  1.01313539e-01 ...  3.33602697e-01
#      3.87100577e-02  1.70233145e-01]
#    [ 5.89847490e-02 -1.60619199e-01  1.70680076e-01 ...  4.33629192e-02
#     -3.56275663e-02 -3.74662466e-02]]
#
#   [[ 1.27437979e-01  1.15359075e-01 -4.37012454e-03 ...  1.43081874e-01
#      1.40908966e-02 -2.77944505e-01]
#    [ 6.24125525e-02  6.36089593e-02  3.04615080e-01 ...  4.19665538e-02
#     -2.13993147e-01  2.34170422e-01]
# ...

# %%
model.save('TanH_Issue.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
